# %% [markdown]
# **Описание проекта**

# %% [markdown]
# Заказчиком проекта является сервис, который предоставляет возможность отслеживать результаты спортсменов по  фигурному катанию на различных соревнованиях. Это может помочь тренерам выстроить грамотный план тренировок и соревнований для будущих чемпионов.
# Необходимо создать решение по автоматическому опеределению от какой спортивной школы выступает спортсмен, основываясь на названии введенном в ручном порядке. Одна и та же школа может быть записана по-разному.
# Необходимо построить модель, которая сможет сверять введенное название с его эталонным написанием.

# %% [markdown]
# **План**

# %% [markdown]
# - Изучить данные – эталонные названия СШ и варианты пользовательского ввода
# - Подготовить обучающий набор данных на основе эталонного датасета
# - Создать модель для подбора наиболее вероятных названий при ошибочном вводе
# - Проанализировать результат и предложить варианты улучшения

# %% [markdown]
# **Описание данных**

# %% [markdown]
# Данные представлены в двух таблицах:
# - Первая с эталонными названиями школ и регионами
# - Вторая с примерами пользовательского ввода названий школ

# %% [markdown]
# # Загрузка библиотек и данных

# %%
# !pip install -U sentence-transformers

# %%
# !pip install nlpaug

# %%
# !pip install transformers[torch]

# %%
# !pip install accelerate -U

# %%
# !pip install datasets

# %%
import pandas as pd
import numpy as np
import random
import torch
from sklearn.model_selection import train_test_split
import warnings
import re
import nlpaug.augmenter as naw
from datasets import Dataset
from torch.utils.data import DataLoader
from sentence_transformers import SentenceTransformer, SentenceTransformerTrainer, InputExample, losses, SentencesDataset
from sentence_transformers.util import semantic_search

# %%
reference = pd.read_csv('/content/Школы.csv')

# %%
sample = pd.read_csv('/content/Примерное написание.csv')

# %%
def data_overview(df):

    # Вывод первых нескольких строк файла
    print("Первые несколько строк файла:")
    print(df.head())
    print("\n")

    # Вывод общей информации о DataFrame
    print("Информация о DataFrame:")
    print(df.info())
    print("\n")

    # Проверка пропусков (абсолютные и относительные значения)
    print("Проверка пропусков (абсолютные значения):")
    print(df.isnull().sum())
    print("\n")

    print("Проверка пропусков (относительные значения):")
    print(df.isnull().mean())
    print("\n")

    # Распределение данных для качественных (числовых) столбцов
    print("Распределение данных для числовых столбцов:")
    print(df.describe())
    print("\n")

    # Уникальные значения для категориальных столбцов
    print("Уникальные значения для категориальных столбцов:")
    for column in df.select_dtypes(include=['object', 'category']).columns:
        print(f"Столбец '{column}':")
        print(df[column].value_counts())
        print("\n")

# %%
data_overview(reference)
# Out:
# Первые несколько строк файла:
#    school_id                  name                region
# 0          1              Авангард    Московская область
# 1          2              Авангард     Ямало-Ненецкий АО
# 2          3               Авиатор  Республика Татарстан
# 3          4                Аврора       Санкт-Петербург
# 4          5  Ice Dream / Айс Дрим       Санкт-Петербург
#
#
# Информация о DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306 entries, 0 to 305
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   school_id  306 non-null    int64
#  1   name       306 non-null    object
#  2   region     306 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 7.3+ KB
# None
#
#
# Проверка пропусков (абсолютные значения):
# school_id    0
# name         0
# region       0
# dtype: int64
#
#
# Проверка пропусков (относительные значения):
# school_id    0.0
# name         0.0
# region       0.0
# dtype: float64
#
#
# Распределение данных для числовых столбцов:
#          school_id
# count   306.000000
# mean    161.820261
# std     137.387368
# min       1.000000
# 25%      77.250000
# 50%     153.500000
# 75%     229.750000
# max    1836.000000
#
#
# Уникальные значения для категориальных столбцов:
# Столбец 'name':
# name
# Олимп           5
# Юность          4
# Айсберг         3
# СШОР №1         3
# СШОР № 2        3
#                ..
# Мастер          1
# МАУ СШ No 7     1
# МАФКК           1
# МАФСУ СШ № 6    1
# О2              1
# Name: count, Length: 263, dtype: int64
#
#
# Столбец 'region':
# region
# Санкт-Петербург          64
# Москва                   29
# Московская область       15
# Свердловская область     10
# Республика Татарстан      9
#                          ..
# Смоленская область        1
# Липецкая область          1
# Забайкальский край        1
# Удмуртская республика     1
# Саратовская область       1
# Name: count, Length: 74, dtype: int64

# %%
data_overview(sample)
# Out:
# Первые несколько строк файла:
#    school_id                                               name
# 0       1836                                       ООО "Триумф"
# 1       1836                                Москва, СК "Триумф"
# 2        610                             СШОР "Надежда Губернии
# 3        610  Саратовская область, ГБУСО "СШОР "Надежда Губе...
# 4        609                                     "СШ "Гвоздика"
#
#
# Информация о DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 895 entries, 0 to 894
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   school_id  895 non-null    int64
#  1   name       895 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 14.1+ KB
# None
#
#
# Проверка пропусков (абсолютные значения):
# school_id    0
# name         0
# dtype: int64
#
#
# Проверка пропусков (относительные значения):
# school_id    0.0
# name         0.0
# dtype: float64
#
#
# Распределение данных для числовых столбцов:
#          school_id
# count   895.000000
# mean    147.048045
# std     116.995100
# min       1.000000
# 25%      73.500000
# 50%     139.000000
# 75%     208.500000
# max    1836.000000
#
#
# Уникальные значения для категориальных столбцов:
# Столбец 'name':
# name
# КФК "Динамо-Санкт-Петербург"                       2
# СК «Мастер»                                        1
# Мастер, Санкт-Петербург                            1
# Мастер                                             1
# ШСФК Маска                                         1
#                                                   ..
# ГБУ ДО СШОР Колпинского района СПб                 1
# СПб ГБУ СШОР Колпинского района                    1
# МО г. Колпино, ГБУ ДО СШОР Колпинского р-на СПб    1
# МО г.Колпино, ГБУ ДО СШОР Колпинского р-на         1
# Тверская область, ГБУ "СШОР по ЛВС"                1
# Name: count, Length: 894, dtype: int64

# %% [markdown]
# **Вывод:** Данных для построения модели очень мало. Таблица с эталонными написаниями содержит только 305 записей. Таблица с размеченными произвольными написаниями названий школ содержит лишь 895 записей. Явные дубли отсутствуют
#
# Приняли решение оставить таблицу с образцами для финального тестирования модели, а для обучения и отладки модели использовать таблицу с эталонными названиями.

# %% [markdown]
# # Обработка таблицы с эталонными названиями школ

# %% [markdown]
# Создадим новую таблицу для анализа данных и создания новых признаков

# %%
features = reference

# %% [markdown]
# Проверим регионы в таблице

# %%
sorted(features['region'].unique())
# Out:
# ['Алтайский край',
#  'Архангельская область',
#  'Астраханская область',
#  'Белгородская область',
#  'Брянская область',
#  'Владимирская область',
#  'Волгоградская область',
#  'Вологодская область',
#  'Воронежская область',
#  'Забайкальский край',
#  'Ивановская область',
#  'Иркутская область',
#  'Калининградская область',
#  'Калужская область',
#  'Кемеровская область',
#  'Кировская область',
#  'Костромская бласть',
#  'Костромская область',
#  'Краснодарский край',
#  'Красноярский край',
#  'Курганская область',
#  'Курская область',
#  'Ленинградская область',
#  'Липецкая область',
#  'Москва',
#  'Московская область',
#  'Мурманская область',
#  'Набережные челны',
#  'Нижегородская область',
#  'Новгородская область',
#  'Новосибирская область',
#  'Омская область',
#  'Оренбургская область',
#  'Орловская область',
#  'Пензенская область',
#  'Пермский край',
#  'Приморский край',
#  'Псковская область',
#  'Республика Башкортостан',
#  'Республика Карелия',
#  'Республика Коми',
#  'Республика Корелия',
#  'Республика Крым',
#  'Республика Марий Эл',
#  'Республика Мордовия',
#  'Республика Саха',
#  'Республика Татарстан',
#  'Республика Чувашия',
#  'Ростовская область',
#  'Рязанская область',
#  'Самарская область',
#  'Санкт-Петербург',
#  'Саранск',
#  'Саратовская область',
#  'Сахалинская область',
#  'Свердловская область',
#  'Севастополь',
#  'Северодвинск ',
#  'Смоленская область',
#  'Ставропольский край',
#  'Тамбовская область',
#  'Тверская область',
#  'Томская область',
#  'Тульская область',
#  'Тюменская область',
#  'Удмуртская Республика',
#  'Удмуртская республика',
#  'ХМАО-Югра',
#  'Хабаровский край',
#  'Челябинская область',
#  'Чувашская Республика',
#  'Чувашская республика',
#  'Ямало-Ненецкий АО',
#  'Ярославская область']

# %% [markdown]
# При анализе списка регионов, нашли ошибки в написании некоторых названий, что привело к появлению неявных дублей. Например - Карелия/Корелия
#
# Так же есть регионы, которые написаны несколькими способами - Республика Чувашия/Чувашская республика.
#
# Так же имеются в списке регионов города
#
# Приняли решение заменить названия на эталонные.

# %%
replacement_dict = {
    'Чувашская республика' : 'Чувашская Республика',
    'Республика Чувашия' : 'Чувашская Республика',
    'Республика Корелия' : 'Республика Карелия',
    'Удмуртская республика' : 'Удмуртская Республика',
    'Саранск' : 'Республика Мордовия',
    'Северодвинск ' : 'Архангельская область',
    'Костромская бласть' : 'Костромская область',
    'Набережные челны' : 'Республика Татарстан',
    'Ямало-Ненецкий АО' : 'Ямало-Ненецкий автономный округ',
    'ХМАО-Югра' : 'Ханты-Мансийский автономный округ - Югра',
    'Республика Саха' : 'Республика Саха'
    }

# %%
features['region'] = features['region'].replace(replacement_dict)

# %%
sorted(features['region'].unique())
# Out:
# ['Алтайский край',
#  'Архангельская область',
#  'Астраханская область',
#  'Белгородская область',
#  'Брянская область',
#  'Владимирская область',
#  'Волгоградская область',
#  'Вологодская область',
#  'Воронежская область',
#  'Забайкальский край',
#  'Ивановская область',
#  'Иркутская область',
#  'Калининградская область',
#  'Калужская область',
#  'Кемеровская область',
#  'Кировская область',
#  'Костромская область',
#  'Краснодарский край',
#  'Красноярский край',
#  'Курганская область',
#  'Курская область',
#  'Ленинградская область',
#  'Липецкая область',
#  'Москва',
#  'Московская область',
#  'Мурманская область',
#  'Нижегородская область',
#  'Новгородская область',
#  'Новосибирская область',
#  'Омская область',
#  'Оренбургская область',
#  'Орловская область',
#  'Пензенская область',
#  'Пермский край',
#  'Приморский край',
#  'Псковская область',
#  'Республика Башкортостан',
#  'Республика Карелия',
#  'Республика Коми',
#  'Республика Крым',
#  'Республика Марий Эл',
#  'Республика Мордовия',
#  'Республика Саха',
#  'Республика Татарстан',
#  'Ростовская область',
#  'Рязанская область',
#  'Самарская область',
#  'Санкт-Петербург',
#  'Саратовская область',
#  'Сахалинская область',
#  'Свердловская область',
#  'Севастополь',
#  'Смоленская область',
#  'Ставропольский край',
#  'Тамбовская область',
#  'Тверская область',
#  'Томская область',
#  'Тульская область',
#  'Тюменская область',
#  'Удмуртская Республика',
#  'Хабаровский край',
#  'Ханты-Мансийский автономный округ - Югра',
#  'Челябинская область',
#  'Чувашская Республика',
#  'Ямало-Ненецкий автономный округ',
#  'Ярославская область']

# %%
features['region'].nunique()
# Out:
# 66

# %% [markdown]
# После очистки названий в списке осталось 66 регионов

# %% [markdown]
# Приняли решение удалить из названий кавычки и некоторые формы организации, такие как ООО, ГБУ, МБУ, ГАУ, РФ, ДО, ФАУ, которые не несут смысловой нагрузки, но усложняют анализ данных.

# %%
# Функция для очистки текста от лишних символов
def clean_text(text):
    #список аббевиатур для удаления
    abbreviations = ['ГАУ', 'МБУ', 'ГБУ', 'РФ', 'ГУ', 'ГБОУ', 'ДО', 'ФАУ', 'ООО', 'ИП']
    #регулярка для их удаления
    pattern = r'\b(?:' + '|'.join(abbreviations) + r')\b'
    text = re.sub(pattern, '', text).strip()
    # создаем регулярное выражение для удаления лишних символов
    regular = r'[\*+\#+\№\"\«\»\+\=+\?+\&\^\.+\;\,+\>+\(\)\/+\:\\+]'
    # удаляем лишние символы
    text = re.sub(regular, '', text)
    # удаляем лишние пробелы
    text = re.sub(r'\s+', ' ', text)
    # возвращаем очищенные данные
    return text

# %%
# создаем список для хранения очищенных данных
cleaned_text = []
# для каждого названия из столбца name
for name in features['name']:
    # очищаем данные
    name = clean_text(name)
    # добавляем очищенные данные в список cleaned_text
    cleaned_text.append(name)
# записываем очищенные данные в новую колонку 'cleaned_text'
features['name'] = cleaned_text

# %% [markdown]
# Приняли решение просмотреть список школ, внутри регионов, для того чтобы исключить возможность появления дополнительных дублей

# %%
features[['name','region']].duplicated().sum()
# Out:
# 6

# %%
features[features[['name','region']].duplicated()]
# Out:
#      school_id          name                region
# 11          12  Академия ФКК   Республика Мордовия
# 39          40      Голубева   Костромская область
# 67          68      Керриган    Республика Карелия
# 186        187          СШ 6    Мурманская область
# 213        214        СШОР 4  Чувашская Республика
# 286        289        Пируэт       Санкт-Петербург

# %% [markdown]
# В таблице нашлись 6 полных дубликата записей, отличающихся только id номером. Приняли решение их удалить

# %%
ind_to_remove = [11, 39, 67, 186, 213, 289]
features = features.drop(ind_to_remove)
features = features.reset_index(drop=True)

# %%
features = features.groupby('region').apply(lambda x: x.sort_values('name')).reset_index(drop=True)
pd.set_option('display.max_rows', None)
features
# Out:
#      school_id                                             name  \
# 0          305                                         Прогресс
# 1           22                                        Беломорец
# 2            9                                        Звездочка
# 3           66                                           Каскад
# 4          159                                        Созвездие
# 5           51                                      ДЮСШ по ЗВС
# 6           26                                           Брянск
# 7           36                                               СК
# 8          178                                         СШ по ФК
# 9           59                                           ДЮСШ 8
# 10          44                                    Дворец Спорта
# 11          46                                           Динамо
# 12         108                                   Мотодром Арена
# 13         241                                           ФФККВО
# 14         176                                        СШ по ЗВС
# 15          31                                           Витязь
# 16          85                                   Ледовый дворец
# 17         181                                             СШ 1
# 18          77                                           Космос
# 19         268                               МКУ ДЮСШ ВОСТОЧНАЯ
# 20         146                                             Рысь
# 21         154                                           Сияние
# 22         245                                Хрустальный конек
# 23         297                                ЧУДО ДЮСОШ СИЯНИЕ
# 24         209                                           СШОР 2
# 25          47                                           Динамо
# 26          58                                           ДЮСШ 7
# 27          60                                            Ермак
# 28         127                                         ООФФК ИО
# 29          71                                     КО СШ по ЗВС
# 30         149                                      Светлогорец
# 31         231           Федерация фигурного катания на коньках
# 32          78                                           Космос
# 33         118                                            Олимп
# 34          98                                       МАФСУ СШ 1
# 35          97                                       МАФСУ СШ 6
# 36         100                                         МБФСУ СШ
# 37          50                                            Дымка
# 38          39                                         Голубева
# 39          13                                        Аллигатор
# 40         144                                      РЦСП по ФФК
# 41         179                                      СШ по ФККиХ
# 42         199                                      СШОР по ФКК
# 43         158                                         Снеговик
# 44          80                                       Красноярск
# 45         139                                          Рассвет
# 46         174                                           СШ ЗВС
# 47         246                                     Центр по ЛВС
# 48          55                                           ДЮСШ 2
# 49         207                                           СШОР 1
# 50         210                                           СШОР 2
# 51          18                                            Арена
# 52          35                                            ВСШОР
# 53         184                                            СШ 11
# 54          10          Академия синхронного катания на коньках
# 55          15                                  Ангелы Плющенко
# 56          20                          Армия фигурного катания
# 57          28                                      Вдохновение
# 58          34                                          Волкова
# 59          75                                 Конек Чайковской
# 60          82                                          Легенда
# 61          96                                            МАФКК
# 62         104                                      МОСГОРСПОРТ
# 63         101                                       Медведково
# 64         102                                            Мечта
# 65         294                         МосСпортОбъект ЛЦ Звезда
# 66         106                                          Москвич
# 67         113                                   Новочебоксарск
# 68         119                                            Олимп
# 69         136                                        ПроСинхро
# 70         138                                          Прусова
# 71         211                                           СШОР 2
# 72         303                                         СетПоинт
# 73         160                                        Созвездие
# 74         161                                       Сокольники
# 75         171                                          Столица
# 76        1836                                           Триумф
# 77         244                                      Хрустальный
# 78         251                                             ЦСКА
# 79         252                                  ЦСКА им СА Жука
# 80         247                            Центр развития спорта
# 81         262                                        Южный Лед
# 82           1                                         Авангард
# 83          14                                Альберта Демченко
# 84          16                                  Ангелы Плющенко
# 85          21                          Армия фигурного катания
# 86          42                                          Давыдов
# 87          70                                  Клин спортивный
# 88          91                                        Лыткарино
# 89          92                                          Ляпкина
# 90         110                                     Наши надежды
# 91         116                                         Одинцово
# 92         129                                        Пахомовой
# 93         148                                            Салют
# 94         227                                            УОР 1
# 95         301                                    ЦФКиС г Лобня
# 96         248                      Центр спортивных технологий
# 97          69                                         Кировска
# 98         186                                             СШ 6
# 99         263                                           Юность
# 100         45                             Дворец спорта Юность
# 101        103                                        Мещерский
# 102         37                                   НО СШОР по ЛВС
# 103        120                                            Олимп
# 104        183                                             СШ 1
# 105        194                                      СШОР по ЛВС
# 106        150                                  Северная Звезда
# 107        233                                      ФОК городец
# 108        166                                  Спорт-индустрия
# 109         23                                           Бердск
# 110        249                                             ЦЗВС
# 111        212                                          СШОР 35
# 112        121                                            Олимп
# 113        203                                           СШОР 1
# 114         84                                Ледовое поколение
# 115        182                                             СШ 1
# 116        304                                        СШ по ЗВС
# 117        611                                      КФК Айсберг
# 118        115                                               О2
# 119        128                                          Орленок
# 120        204                                           СШОР 1
# 121        168                                            Старт
# 122        225                                           Триумф
# 123         32                                          Владлед
# 124        133                                            Полюс
# 125        122                                            Олимп
# 126        292                                          АНО ШФК
# 127        302                                             СШ 2
# 128        205                                           СШОР 1
# 129        147                                    Салаватинвест
# 130        235                                           ФФК РБ
# 131         56                                           ДЮСШ 2
# 132         67                                         Керриган
# 133        190                                             СШ 6
# 134        237                                             ФФКК
# 135        109                                          МУ СШ 1
# 136        299                                     РФСОО ФФККРК
# 137        218                                           СШОР 1
# 138        151                                 Северная Олимпия
# 139        239                                          ФФКК РК
# 140          6                                          Айсберг
# 141        189                                             СШ 4
# 142        162                             Союз мастеров спорта
# 143        177                                        СШ по ЛВС
# 144         11                                     Академия ФКК
# 145        219                                           СШОР 1
# 146        200                                      СШОР по ФКК
# 147        202                                      СШОР по ФФК
# 148        197              СШОР по фигурному катанию на конька
# 149        140                                     РОО СФФК РСЯ
# 150        142                                      РССШ по ЗВС
# 151          3                                          Авиатор
# 152         43                                         Движение
# 153         88                                          Ледокол
# 154        230                                          МО ЦСКА
# 155        130                                         ПГУФКСиТ
# 156        143                                            РСШОР
# 157        201                                   СШОР по ФККиШТ
# 158        153                                              СиТ
# 159        172                                           Стрела
# 160        258                                            Челны
# 161         83                                 Ледовая академия
# 162        137                                     Профессионал
# 163        141                                           РОФФКК
# 164        155                                        СК РОФФКК
# 165        216                                           СШОР 6
# 166          7                                          Айсберг
# 167        124                                      Олимпийский
# 168        300                                 РО ХК Рязань-ВДВ
# 169        217                                           СШОР 6
# 170         33                                          Волгарь
# 171         54                                          ДЮСШ 10
# 172        107  Московская академия фигурного катания на конька
# 173        206                                        СШОР No 1
# 174          5                               Ice Dream Айс Дрим
# 175        283                                      Proice Kids
# 176          4                                           Аврора
# 177         25                                Бриллиантовый лед
# 178         27                                      Буревестник
# 179         29                                          Вершина
# 180         30                                       Вилеса Айс
# 181        284                                            ГЛАЙД
# 182        274                     Голден Айс Петергоф СШ Манеж
# 183         38                                       Голден айс
# 184         57                                           ДЮСШ 4
# 185         52                                ДЮСШ СК Юбилейный
# 186        291                                          Динамит
# 187         48                           Динамо Санкт-Петербург
# 188         49                                         Династия
# 189         61                                           Звезда
# 190         62                                     Звездный лед
# 191         63                                    Золотой конек
# 192         64                                  Золотые надежды
# 193        271                                          Иванова
# 194        273                                           Каскад
# 195         79                                   Красная звезда
# 196        275                                  ЛЕДОВАЯ ИСТОРИЯ
# 197         89                                        Локомотив
# 198         93                                            Маска
# 199         94                                           Мастер
# 200        277                    НП КФК Динамо-Санкт-Петербург
# 201        111                                      Невский лед
# 202        125                                          ОЛИМПИЯ
# 203        285        Отделение фигурного катания Ника Клуб СБС
# 204        289                                           Пируэт
# 205        131                                           Пируэт
# 206        134                                           Прибой
# 207        286                               СК ФК Ice Prestige
# 208        272                                   СК ФК Open Ice
# 209        105                                СК ФК Т Москвиной
# 210        288                                         СТАРТАЙС
# 211        278                                 СФК Империя Льда
# 212        281                    СФК Серпантин И П Шалимова ТА
# 213        287       СФК УЗОР Баранчикова Наталия Александровна
# 214        282     СШ ОРК филиала МО ЦСКА СКА г Санкт-Петербург
# 215        220                                           СШОР 1
# 216        208                        СШОР 1 Московского района
# 217        192                          СШОР Колпинского района
# 218        198             СШОР по фигурному катанию на коньках
# 219        276                                 Северная Столица
# 220        152                                  Северное Сияние
# 221        279                                    Созвездие Айс
# 222        164                                          Спартак
# 223        170                                         Стартайс
# 224        223                                            ТИТУЛ
# 225         17                         ТОП ТИМ - лучшая команда
# 226        222                                            Темпо
# 227        229                                          Фаворит
# 228        156                               Хоккейный клуб СКА
# 229        250              ЦОП по фигурному катанию на коньках
# 230        254                  ЦФКСиЗ Василеостровского района
# 231        253                 ЦФКСиЗ Красногвардейского района
# 232        256                        ЦФКСиЗ Московского района
# 233        270                           ЦФКСиЗ Невского района
# 234        257                       ЦФКСиЗ Фрунзенского района
# 235        259                                          Чемпион
# 236         24                              Школа ФК Е Бережной
# 237        280                                     Энергия льда
# 238        610                            СШОР Надежда Губернии
# 239         81                                         Кристалл
# 240        243                                     Холмск-Арена
# 241          8                                          Айсберг
# 242         90                                        Локомотив
# 243         72                    МАУ СШ им Александра Козицына
# 244        296                              МБОУ СШ 8 Локомотив
# 245        112                                             НЛФК
# 246        126                                          ОЛИМПИЯ
# 247        185                                            СШ 19
# 248        169                                            Старт
# 249        260                                          Энергия
# 250        264                                           Юность
# 251        298                                 АНО СК ЮНАРМЕЙЦЫ
# 252        180                            СШ по хоккею с шайбой
# 253        175                                           СШ ЗВС
# 254        191                                 СШ гНевинномысск
# 255         99                                        СШ по ЗВС
# 256        163                             Союз мастеров спорта
# 257        167                                 Ставрополь Арена
# 258        236                                           ФФК СК
# 259        242                                           ФФККСК
# 260        221                                           СШОР 3
# 261         41                                           Гусева
# 262         74                                  Конаковский лед
# 263        193                                      СШОР по ЗВС
# 264        195                                      СШОР по ЛВС
# 265        196                     СШОР по ледовым видам спорта
# 266        232                                              ФКК
# 267        234                                              ФФК
# 268        157                                            Смена
# 269         86                                   Ледовый дворец
# 270        117                                           ОКСШОР
# 271        295                                        ТО ОКСШОР
# 272         53                                        ДЮСШ No 1
# 273        135                                           Прибой
# 274         65                                          Ижсталь
# 275        609                                      СШ Гвоздика
# 276        228                                             УФФК
# 277        132                                           Пируэт
# 278         87                            Ледовый дворец спорта
# 279        123                                         Олимпиец
# 280        173                                               СШ
# 281        238                                             ФФКК
# 282        265                                           Юность
# 283         73                                Команда Дмитриева
# 284         95                                      МАУ СШ No 7
# 285        145                                          РЦСПЗВС
# 286        188                                             СШ 7
# 287        224                                            Тодес
# 288        226                                       Ужный урал
# 289        261                                     Южное сияние
# 290        213                                           СШОР 4
# 291        165                                          Спартак
# 292        266                                           Юность
# 293          2                                         Авангард
# 294         19                                           Арктур
# 295         76                                          Контакт
# 296        114                                    Новый уренгой
# 297        240                                        ФФКК ЯНАО
# 298        267                                             Ямал
# 299        215                                           СШОР 4
#
#                                        region
# 0                              Алтайский край
# 1                       Архангельская область
# 2                       Архангельская область
# 3                       Архангельская область
# 4                        Астраханская область
# 5                        Белгородская область
# 6                            Брянская область
# 7                            Брянская область
# 8                            Брянская область
# 9                        Владимирская область
# 10                       Владимирская область
# 11                       Владимирская область
# 12                       Владимирская область
# 13                       Владимирская область
# 14                      Волгоградская область
# 15                        Вологодская область
# 16                        Вологодская область
# 17                        Вологодская область
# 18                        Воронежская область
# 19                        Воронежская область
# 20                        Воронежская область
# 21                        Воронежская область
# 22                        Воронежская область
# 23                        Воронежская область
# 24                         Забайкальский край
# 25                         Ивановская область
# 26                          Иркутская область
# 27                          Иркутская область
# 28                          Иркутская область
# 29                    Калининградская область
# 30                    Калининградская область
# 31                    Калининградская область
# 32                          Калужская область
# 33                          Калужская область
# 34                        Кемеровская область
# 35                        Кемеровская область
# 36                        Кемеровская область
# 37                          Кировская область
# 38                        Костромская область
# 39                         Краснодарский край
# 40                         Краснодарский край
# 41                         Краснодарский край
# 42                         Краснодарский край
# 43                         Краснодарский край
# 44                          Красноярский край
# 45                          Красноярский край
# 46                          Красноярский край
# 47                          Красноярский край
# 48                         Курганская область
# 49                         Курганская область
# 50                         Курганская область
# 51                            Курская область
# 52                      Ленинградская область
# 53                           Липецкая область
# 54                                     Москва
# 55                                     Москва
# 56                                     Москва
# 57                                     Москва
# 58                                     Москва
# 59                                     Москва
# 60                                     Москва
# 61                                     Москва
# 62                                     Москва
# 63                                     Москва
# 64                                     Москва
# 65                                     Москва
# 66                                     Москва
# 67                                     Москва
# 68                                     Москва
# 69                                     Москва
# 70                                     Москва
# 71                                     Москва
# 72                                     Москва
# 73                                     Москва
# 74                                     Москва
# 75                                     Москва
# 76                                     Москва
# 77                                     Москва
# 78                                     Москва
# 79                                     Москва
# 80                                     Москва
# 81                                     Москва
# 82                         Московская область
# 83                         Московская область
# 84                         Московская область
# 85                         Московская область
# 86                         Московская область
# 87                         Московская область
# 88                         Московская область
# 89                         Московская область
# 90                         Московская область
# 91                         Московская область
# 92                         Московская область
# 93                         Московская область
# 94                         Московская область
# 95                         Московская область
# 96                         Московская область
# 97                         Мурманская область
# 98                         Мурманская область
# 99                         Мурманская область
# 100                     Нижегородская область
# 101                     Нижегородская область
# 102                     Нижегородская область
# 103                     Нижегородская область
# 104                     Нижегородская область
# 105                     Нижегородская область
# 106                     Нижегородская область
# 107                     Нижегородская область
# 108                      Новгородская область
# 109                     Новосибирская область
# 110                     Новосибирская область
# 111                            Омская область
# 112                      Оренбургская область
# 113                      Оренбургская область
# 114                         Орловская область
# 115                        Пензенская область
# 116                        Пензенская область
# 117                             Пермский край
# 118                             Пермский край
# 119                             Пермский край
# 120                             Пермский край
# 121                             Пермский край
# 122                             Пермский край
# 123                           Приморский край
# 124                           Приморский край
# 125                         Псковская область
# 126                   Республика Башкортостан
# 127                   Республика Башкортостан
# 128                   Республика Башкортостан
# 129                   Республика Башкортостан
# 130                   Республика Башкортостан
# 131                        Республика Карелия
# 132                        Республика Карелия
# 133                        Республика Карелия
# 134                        Республика Карелия
# 135                           Республика Коми
# 136                           Республика Коми
# 137                           Республика Коми
# 138                           Республика Коми
# 139                           Республика Коми
# 140                           Республика Крым
# 141                           Республика Крым
# 142                           Республика Крым
# 143                       Республика Марий Эл
# 144                       Республика Мордовия
# 145                       Республика Мордовия
# 146                       Республика Мордовия
# 147                       Республика Мордовия
# 148                       Республика Мордовия
# 149                           Республика Саха
# 150                           Республика Саха
# 151                      Республика Татарстан
# 152                      Республика Татарстан
# 153                      Республика Татарстан
# 154                      Республика Татарстан
# 155                      Республика Татарстан
# 156                      Республика Татарстан
# 157                      Республика Татарстан
# 158                      Республика Татарстан
# 159                      Республика Татарстан
# 160                      Республика Татарстан
# 161                        Ростовская область
# 162                        Ростовская область
# 163                        Ростовская область
# 164                        Ростовская область
# 165                        Ростовская область
# 166                         Рязанская область
# 167                         Рязанская область
# 168                         Рязанская область
# 169                         Рязанская область
# 170                         Самарская область
# 171                         Самарская область
# 172                         Самарская область
# 173                         Самарская область
# 174                           Санкт-Петербург
# 175                           Санкт-Петербург
# 176                           Санкт-Петербург
# 177                           Санкт-Петербург
# 178                           Санкт-Петербург
# 179                           Санкт-Петербург
# 180                           Санкт-Петербург
# 181                           Санкт-Петербург
# 182                           Санкт-Петербург
# 183                           Санкт-Петербург
# 184                           Санкт-Петербург
# 185                           Санкт-Петербург
# 186                           Санкт-Петербург
# 187                           Санкт-Петербург
# 188                           Санкт-Петербург
# 189                           Санкт-Петербург
# 190                           Санкт-Петербург
# 191                           Санкт-Петербург
# 192                           Санкт-Петербург
# 193                           Санкт-Петербург
# 194                           Санкт-Петербург
# 195                           Санкт-Петербург
# 196                           Санкт-Петербург
# 197                           Санкт-Петербург
# 198                           Санкт-Петербург
# 199                           Санкт-Петербург
# 200                           Санкт-Петербург
# 201                           Санкт-Петербург
# 202                           Санкт-Петербург
# 203                           Санкт-Петербург
# 204                           Санкт-Петербург
# 205                           Санкт-Петербург
# 206                           Санкт-Петербург
# 207                           Санкт-Петербург
# 208                           Санкт-Петербург
# 209                           Санкт-Петербург
# 210                           Санкт-Петербург
# 211                           Санкт-Петербург
# 212                           Санкт-Петербург
# 213                           Санкт-Петербург
# 214                           Санкт-Петербург
# 215                           Санкт-Петербург
# 216                           Санкт-Петербург
# 217                           Санкт-Петербург
# 218                           Санкт-Петербург
# 219                           Санкт-Петербург
# 220                           Санкт-Петербург
# 221                           Санкт-Петербург
# 222                           Санкт-Петербург
# 223                           Санкт-Петербург
# 224                           Санкт-Петербург
# 225                           Санкт-Петербург
# 226                           Санкт-Петербург
# 227                           Санкт-Петербург
# 228                           Санкт-Петербург
# 229                           Санкт-Петербург
# 230                           Санкт-Петербург
# 231                           Санкт-Петербург
# 232                           Санкт-Петербург
# 233                           Санкт-Петербург
# 234                           Санкт-Петербург
# 235                           Санкт-Петербург
# 236                           Санкт-Петербург
# 237                           Санкт-Петербург
# 238                       Саратовская область
# 239                       Сахалинская область
# 240                       Сахалинская область
# 241                      Свердловская область
# 242                      Свердловская область
# 243                      Свердловская область
# 244                      Свердловская область
# 245                      Свердловская область
# 246                      Свердловская область
# 247                      Свердловская область
# 248                      Свердловская область
# 249                      Свердловская область
# 250                      Свердловская область
# 251                               Севастополь
# 252                        Смоленская область
# 253                       Ставропольский край
# 254                       Ставропольский край
# 255                       Ставропольский край
# 256                       Ставропольский край
# 257                       Ставропольский край
# 258                       Ставропольский край
# 259                       Ставропольский край
# 260                        Тамбовская область
# 261                          Тверская область
# 262                          Тверская область
# 263                          Тверская область
# 264                          Тверская область
# 265                          Тверская область
# 266                          Тверская область
# 267                          Тверская область
# 268                           Томская область
# 269                          Тульская область
# 270                          Тульская область
# 271                          Тульская область
# 272                         Тюменская область
# 273                         Тюменская область
# 274                     Удмуртская Республика
# 275                     Удмуртская Республика
# 276                     Удмуртская Республика
# 277                          Хабаровский край
# 278  Ханты-Мансийский автономный округ - Югра
# 279  Ханты-Мансийский автономный округ - Югра
# 280  Ханты-Мансийский автономный округ - Югра
# 281  Ханты-Мансийский автономный округ - Югра
# 282  Ханты-Мансийский автономный округ - Югра
# 283                       Челябинская область
# 284                       Челябинская область
# 285                       Челябинская область
# 286                       Челябинская область
# 287                       Челябинская область
# 288                       Челябинская область
# 289                       Челябинская область
# 290                      Чувашская Республика
# 291                      Чувашская Республика
# 292                      Чувашская Республика
# 293           Ямало-Ненецкий автономный округ
# 294           Ямало-Ненецкий автономный округ
# 295           Ямало-Ненецкий автономный округ
# 296           Ямало-Ненецкий автономный округ
# 297           Ямало-Ненецкий автономный округ
# 298           Ямало-Ненецкий автономный округ
# 299                       Ярославская область

# %% [markdown]
# Просмотрев весь список, отсортированный по регионам, мы нашли дополнительные дубли, не очевидные для машинного поиска. Приняли решение их удалить.

# %%
ind_to_remove = [147, 148, 164, 255, 259, 136, 205, 200, 264, 271]
features = features.drop(ind_to_remove)
features = features.reset_index(drop=True)

# %%
pd.reset_option('display.max_rows')

# %% [markdown]
# Теперь список очищен от дубликатов, которые можно обнаружить на первый взгляд и готов к дальнейшей работе.

# %% [markdown]
# # Создание новых признаков

# %% [markdown]
# Добавим в таблицу со школами сокращенные названия регионов - это данные взятые из "Правила вида спорта "стрельба из арбалета" (утв. приказом Минспорта России от 22.02.2019 N 157) раздел - СУБЪЕКТЫ РОССИЙСКОЙ ФЕДЕРАЦИИ, СОКРАЩЕННЫЕ НАЗВАНИЯ, ПРИНЯТЫЕ ДЛЯ ПРОТОКОЛОВ СОРЕВНОВАНИЙ.
#
# Создам словарь для названия региона и его сокращения

# %%
abbrev = pd.read_excel('/content/сокращения регионов.xlsx')

# %%
abbrev.loc[79]
# Out:
# N                                        80
# Субъект РФ                город Севастополь
# Код для протокола                       СВС
# Административный центр          Севастополь
# Name: 79, dtype: object

# %%
abbrev.head(5)
# Out:
#    N               Субъект РФ Код для протокола Административный центр
# 0  1        Республика Адыгея               АДГ                 Майкоп
# 1  2         Республика Алтай               АЛТ          Горно-Алтайск
# 2  3  Республика Башкортостан               БАШ                    Уфа
# 3  4       Республика Бурятия               БУР               Улан-Удэ
# 4  5      Республика Дагестан               ДАГ              Махачкала

# %% [markdown]
# Удалю из названия регионов слово город

# %%
abbrev['Субъект РФ'] = abbrev['Субъект РФ'].str.replace('город ', '')

# %%
abbrev['Субъект РФ'] = abbrev['Субъект РФ'].str.replace(r'\(.*?\)', '', regex=True)

# %%
region_to_abbrev = dict(zip(abbrev['Субъект РФ'],abbrev['Код для протокола']))

# %%
features['reg_abbrev'] = features['region'].map(region_to_abbrev)

# %%
features.sample(3)
# Out:
#      school_id             name            region reg_abbrev
# 123         32          Владлед   Приморский край        ПРК
# 192        275  ЛЕДОВАЯ ИСТОРИЯ   Санкт-Петербург        СПБ
# 260         86   Ледовый дворец  Тульская область        ТУЛ

# %%
features[features['reg_abbrev'].isna()]
# Out:
#      school_id          name           region reg_abbrev
# 146        140  РОО СФФК РСЯ  Республика Саха        NaN
# 147        142   РССШ по ЗВС  Республика Саха        NaN

# %%
features['reg_abbrev'] = features['reg_abbrev'].fillna('САХ')
features[features['reg_abbrev'].isna()]
# Out:
# Empty DataFrame
# Columns: [school_id, name, region, reg_abbrev]
# Index: []

# %% [markdown]
# Кроме таких признаных сокращений регионов часто используются просто первые буквы названий региона, создадим колонку с таким признаком. Республика Саха = РС

# %%
def extract_first_letters(text):
  words = text.split() #разбиваем название региона на слова
  first_letters = [word[0].upper() for word in words]
  return ''.join(first_letters)

# %%
features['first_letters'] = features['region'].apply(extract_first_letters)

# %%
features.sample(3)
# Out:
#      school_id            name                region reg_abbrev first_letters
# 4          159       Созвездие  Астраханская область        АСТ            АО
# 191         79  Красная звезда       Санкт-Петербург        СПБ             С
# 233         81        Кристалл   Сахалинская область        САХ            СО

# %%
features[features['first_letters'].str.len() == 1].sample(3)
# Out:
#      school_id                             name           region reg_abbrev  \
# 224        254  ЦФКСиЗ Василеостровского района  Санкт-Петербург        СПБ
# 230         24              Школа ФК Е Бережной  Санкт-Петербург        СПБ
# 181         52                ДЮСШ СК Юбилейный  Санкт-Петербург        СПБ
#
#     first_letters
# 224             С
# 230             С
# 181             С

# %% [markdown]
# У городов федерального значения из первых букв остается только одна - заменим это сокращение на тоже общепринятые.Для Москвы часто упротребимое сокращение Мос, для Санкт-Петербурга - СПб

# %%
city_codes = {
    'Москва' : 'Мос',
    'Санкт-Петербург' : 'СПб'
}

def assign_code(city, code): #функция для замены значений для Москвы и Санкт-Петербурга
  if city in city_codes:
    return city_codes[city]
  else:
    return code #оставляем исходное значение, если город другой

features['first_letters'] = features.apply(
    lambda row: assign_code(row['region'], row['first_letters']), axis=1
    )

# %%
features.sample(3)
# Out:
#     school_id          name                   region reg_abbrev first_letters
# 71        211        СШОР 2                   Москва        МСК           Мос
# 29         71  КО СШ по ЗВС  Калининградская область        КЛГ            КО
# 68        119         Олимп                   Москва        МСК           Мос

# %% [markdown]
# Для дальнейшего сравнения создадим эталонное название составленное из Наименования школы и региона - title

# %% [markdown]
# Так же создадим новые признаки из сочетаний названия школы + региона в разном порядке и с сокращениями

# %%
# Функция для создания новых столбцов по шаблону
def create_new_column(df, new_col_name, template):
    df[new_col_name] = df.apply(lambda row: template.format(**row), axis=1)

# Шаблоны для новых столбцов
templates = {
    'title': '{name} {region}',
    'name2': '{name} {reg_abbrev}',
    'name3': '{name} {first_letters}',
    'name4': '{region} {name}',
    'name5': '{reg_abbrev} {name}',
    'name6': '{first_letters} {name}',
}

# Создание новых столбцов на основе шаблонов
for new_col_name, template in templates.items():
    create_new_column(features, new_col_name, template)

# %%
features.sample(10)
# Out:
#      school_id             name                 region reg_abbrev  \
# 112        121            Олимп   Оренбургская область        ОРЕ
# 101        103        Мещерский  Нижегородская область        НЖГ
# 160        141           РОФФКК     Ростовская область        РСТ
# 154        201   СШОР по ФККиШТ   Республика Татарстан        ТАТ
# 217        170         Стартайс        Санкт-Петербург        СПБ
# 98         186             СШ 6     Мурманская область        МУР
# 209        220           СШОР 1        Санкт-Петербург        СПБ
# 192        275  ЛЕДОВАЯ ИСТОРИЯ        Санкт-Петербург        СПБ
# 4          159        Созвездие   Астраханская область        АСТ
# 140        189             СШ 4        Республика Крым        КРМ
#
#     first_letters                                title                name2  \
# 112            ОО           Олимп Оренбургская область            Олимп ОРЕ
# 101            НО      Мещерский Нижегородская область        Мещерский НЖГ
# 160            РО            РОФФКК Ростовская область           РОФФКК РСТ
# 154            РТ  СШОР по ФККиШТ Республика Татарстан   СШОР по ФККиШТ ТАТ
# 217           СПб             Стартайс Санкт-Петербург         Стартайс СПБ
# 98             МО              СШ 6 Мурманская область             СШ 6 МУР
# 209           СПб               СШОР 1 Санкт-Петербург           СШОР 1 СПБ
# 192           СПб      ЛЕДОВАЯ ИСТОРИЯ Санкт-Петербург  ЛЕДОВАЯ ИСТОРИЯ СПБ
# 4              АО       Созвездие Астраханская область        Созвездие АСТ
# 140            РК                 СШ 4 Республика Крым             СШ 4 КРМ
#
#                    name3                                name4  \
# 112             Олимп ОО           Оренбургская область Олимп
# 101         Мещерский НО      Нижегородская область Мещерский
# 160            РОФФКК РО            Ростовская область РОФФКК
# 154    СШОР по ФККиШТ РТ  Республика Татарстан СШОР по ФККиШТ
# 217         Стартайс СПб             Санкт-Петербург Стартайс
# 98               СШ 6 МО              Мурманская область СШ 6
# 209           СШОР 1 СПб               Санкт-Петербург СШОР 1
# 192  ЛЕДОВАЯ ИСТОРИЯ СПб      Санкт-Петербург ЛЕДОВАЯ ИСТОРИЯ
# 4           Созвездие АО       Астраханская область Созвездие
# 140              СШ 4 РК                 Республика Крым СШ 4
#
#                    name5                name6
# 112            ОРЕ Олимп             ОО Олимп
# 101        НЖГ Мещерский         НО Мещерский
# 160           РСТ РОФФКК            РО РОФФКК
# 154   ТАТ СШОР по ФККиШТ    РТ СШОР по ФККиШТ
# 217         СПБ Стартайс         СПб Стартайс
# 98              МУР СШ 6              МО СШ 6
# 209           СПБ СШОР 1           СПб СШОР 1
# 192  СПБ ЛЕДОВАЯ ИСТОРИЯ  СПб ЛЕДОВАЯ ИСТОРИЯ
# 4          АСТ Созвездие         АО Созвездие
# 140             КРМ СШ 4              РК СШ 4

# %%
features.shape
# Out:
# (290, 11)

# %%
features.columns
# Out:
# Index(['school_id', 'name', 'region', 'reg_abbrev', 'first_letters', 'title',
#        'name2', 'name3', 'name4', 'name5', 'name6'],
#       dtype='object')

# %% [markdown]
# Добавлю так же признаки с ошибкой в написании названия школы

# %%
# Функция для создания ошибок в строке
def introduce_typo(name):
    if len(name) > 1:
        pos = random.randint(0, len(name) - 1)
        random_char = random.choice('абвгдеёжзийклмнопрстуфхцчшщъыьэюя ЙЦУКЕНГШЩЗХЪФЫВАПРОЛДЖЭЯЧСМИТЬБЮ')
        name = name[:pos] + random_char + name[pos + 1:]
    return name


def create_columns_with_typos(df, columns_to_process, num_columns_with_typos=3):
    for col in columns_to_process:
        for i in range(1, num_columns_with_typos + 1):
            new_col_name = f'{col}with_typos{i}'
            df[new_col_name] = df[col].apply(lambda x: introduce_typo(x))

# Список колонок, для которых нужно создать ошибки
columns_to_process = ['title', 'name', 'name2', 'name3', 'name4', 'name5', 'name6']

# Создание новых колонок с ошибками
create_columns_with_typos(features, columns_to_process)

print(features.head(1))
# Out:
#    school_id      name          region reg_abbrev first_letters  \
# 0        305  Прогресс  Алтайский край        АЛТ            АК
#
#                      title         name2        name3  \
# 0  Прогресс Алтайский край  Прогресс АЛТ  Прогресс АК
#
#                      name4         name5  ... name3with_typos3  \
# 0  Алтайский край Прогресс  АЛТ Прогресс  ...      Нрогресс АК
#
#           name4with_typos1         name4with_typos2         name4with_typos3  \
# 0  Алтайский край Прозресс  Алтайский край ПрогреАс  Алшайский край Прогресс
#
#   name5with_typos1 name5with_typos2 name5with_typos3 name6with_typos1  \
# 0     АлТ Прогресс     АЛТ Нрогресс     АЛТ Прогрцсс      АК Пригресс
#
#   name6with_typos2 name6with_typos3
# 0      Ао Прогресс      АК Прпгресс
#
# [1 rows x 32 columns]

# %%
features.columns
# Out:
# Index(['school_id', 'name', 'region', 'reg_abbrev', 'first_letters', 'title',
#        'name2', 'name3', 'name4', 'name5', 'name6', 'titlewith_typos1',
#        'titlewith_typos2', 'titlewith_typos3', 'namewith_typos1',
#        'namewith_typos2', 'namewith_typos3', 'name2with_typos1',
#        'name2with_typos2', 'name2with_typos3', 'name3with_typos1',
#        'name3with_typos2', 'name3with_typos3', 'name4with_typos1',
#        'name4with_typos2', 'name4with_typos3', 'name5with_typos1',
#        'name5with_typos2', 'name5with_typos3', 'name6with_typos1',
#        'name6with_typos2', 'name6with_typos3'],
#       dtype='object')

# %%
features.shape
# Out:
# (290, 32)

# %%
features.loc[features['school_id']==162]
# Out:
#      school_id                  name           region reg_abbrev  \
# 141        162  Союз мастеров спорта  Республика Крым        КРМ
#
#     first_letters                                 title  \
# 141            РК  Союз мастеров спорта Республика Крым
#
#                         name2                    name3  \
# 141  Союз мастеров спорта КРМ  Союз мастеров спорта РК
#
#                                     name4                     name5  ...  \
# 141  Республика Крым Союз мастеров спорта  КРМ Союз мастеров спорта  ...
#
#             name3with_typos3                      name4with_typos1  \
# 141  Союз мастеров Рпорта РК  Республика Крым СТюз мастеров спорта
#
#                          name4with_typos2  \
# 141  Республика Крым Союзчмастеров спорта
#
#                          name4with_typos3          name5with_typos1  \
# 141  РесЧублика Крым Союз мастеров спорта  КРМ Союз мастероб спорта
#
#              name5with_typos2          name5with_typos3  \
# 141  ГРМ Союз мастеров спорта  КРМ Союз мастеров мпорта
#
#             name6with_typos1         name6with_typos2         name6with_typos3
# 141  РК Союз мастпров спорта  РК Союз мастеров сцорта  РКяСоюз мастеров спорта
#
# [1 rows x 32 columns]

# %% [markdown]
# Создали достаточно данных, для того чтобы провести обучение модели. Удалим все строки, которые не подходят для обучения.

# %%
features = features.drop(columns=['region', 'reg_abbrev', 'first_letters'])

# %%
features.sample(3)
# Out:
#      school_id         name                            title            name2  \
# 74         161   Сокольники                Сокольники Москва   Сокольники МСК
# 247        175       СШ ЗВС       СШ ЗВС Ставропольский край       СШ ЗВС СТВ
# 274         95  МАУ СШ No 7  МАУ СШ No 7 Челябинская область  МАУ СШ No 7 ЧЕЛ
#
#               name3                            name4            name5  \
# 74   Сокольники Мос                Москва Сокольники   МСК Сокольники
# 247       СШ ЗВС СК       Ставропольский край СШ ЗВС       СТВ СШ ЗВС
# 274  МАУ СШ No 7 ЧО  Челябинская область МАУ СШ No 7  ЧЕЛ МАУ СШ No 7
#
#               name6                 titlewith_typos1  \
# 74   Мос Сокольники                СокоФьники Москва
# 247       СК СШ ЗВС       СШ ЗВС СтОвропольский край
# 274  ЧО МАУ СШ No 7  МАУ СШ No 7 Челябёнская область
#
#                     titlewith_typos2  ... name3with_typos3  \
# 74                 Сокольники МосквБ  ...   Сокольникм Мос
# 247       СШ ЗВС Стаэропольский край  ...        СШ ЗВС Сщ
# 274  МАш СШ No 7 Челябинская область  ...   МАУ СШ NoЗ7 ЧО
#
#                     name4with_typos1                 name4with_typos2  \
# 74                 Москяа Сокольники                Москва СокольникС
# 247       Стайропольский край СШ ЗВС       Ставропольский край ТШ ЗВС
# 274  Чефябинская область МАУ СШ No 7  Челябинская омласть МАУ СШ No 7
#
#                     name4with_typos3 name5with_typos1 name5with_typos2  \
# 74                 МоРква Сокольники   МСК СокольСики   МСК Сшкольники
# 247       СтавропольскШй край СШ ЗВС       СТВ ЗШ ЗВС       тТВ СШ ЗВС
# 274  Челябинская облъсть МАУ СШ No 7  ЧЕЛ МАУ СШ аo 7  ЧЕЛ МАУ СШ NС 7
#
#     name5with_typos3 name6with_typos1 name6with_typos2 name6with_typos3
# 74    МСК Сокольчики   Мос СокоРьники   Моь Сокольники   Мос Соколиники
# 247       СТВжСШ ЗВС        СК СШ ЗНС        СО СШ ЗВС        Ср СШ ЗВС
# 274  ЧЕЛ МАУ СШ No 7   ЧО МАУ СШ вo 7   ЧО МАи СШ No 7   ЧО МАУ СШ фo 7
#
# [3 rows x 29 columns]

# %% [markdown]
# Преобразую широкую таблицу в вертикальную, сохранив верные идентификаторы школ.

# %%
schools_features_melt = features.melt(id_vars=['school_id', 'title'], var_name='name_type', value_name='value')

# %%
schools_features_melt = schools_features_melt.drop(columns=['name_type'])

# %%
schools_features_melt = schools_features_melt.sample(frac=1).reset_index(drop=True)

# %%
schools_features_melt.sample(5)
# Out:
#       school_id                                   title  \
# 3645         59             ДЮСШ 8 Владимирская область
# 3964        190                 СШ 6 Республика Карелия
# 5462         19  Арктур Ямало-Ненецкий автономный округ
# 6227        110         Наши надежды Московская область
# 6142        247            Центр развития спорта Москва
#
#                                        value
# 3645                               ВО ДЮЕШ 8
# 3964                 Республика Карелия СШ 6
# 5462  Арктур Ямало-Ненецкий автономный окЧуг
# 6227         Московская область Наши надежды
# 6142            Москва Центр развитиЕ спорта

# %%
train, test = train_test_split(schools_features_melt, test_size=0.2, random_state=123)

# %%
train.shape
# Out:
# (6264, 3)

# %%
test.shape
# Out:
# (1566, 3)

# %% [markdown]
# **Вывод:** В процессе работы были созданы новые признаки для дальнейшей работы с машинным обучением. Из датасета, состоящего из 305 записей был создан обучающий набор из 7830 строк. Датасет был расширен путем добавления различных комбинаций из названия + региона, аббервиатуры региона, его сокращения, а так же путем внесения орфографических ошибок в получившееся наименование. Для дальнейшей работы приняли решение разделить его на обучающий и тестовый датасет в пропорции 80% на 20%.

# %% [markdown]
# # LaBSE from the box

# %% [markdown]
# Решила закодировать названия в эмбеддинги. Для кодирования использую модель LaBSE из sentence-transformers с huggingface. Эту модель можно использовать для отображения 109 языков в общее векторное пространство.
# Создам модель и функцию для кодирования

# %%
model = SentenceTransformer('sentence-transformers/LaBSE')
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/461 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/2.22k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/804 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.88G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/397 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/5.22M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.62M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/2.36M [00:00<?, ?B/s]
# 2_Dense/config.json:   0%|          | 0.00/114 [00:00<?, ?B/s]

# %% [markdown]
# Кодируем целевые названия в эмбеддинги

# %%
corpus = model.encode(features.title.values)

# %%
query = model.encode(test.value.values)

# %%
model_search = semantic_search(query, corpus, top_k=1)

# %%
test['search_id'] = [x[0]['corpus_id'] for x in model_search]

# %%
test['candidate_name'] = features.title.values[test.search_id.values]
test = test.drop(columns=['search_id'])

# %%
test.sample(10)
# Out:
#       school_id                                            title  \
# 222         279                    Созвездие Айс Санкт-Петербург
# 2014        243                 Холмск-Арена Сахалинская область
# 4153        219                       СШОР 1 Республика Мордовия
# 2706        119                                     Олимп Москва
# 7730         78                         Космос Калужская область
# 2932        254  ЦФКСиЗ Василеостровского района Санкт-Петербург
# 3739        104                               МОСГОРСПОРТ Москва
# 5028        151                 Северная Олимпия Республика Коми
# 6549        192          СШОР Колпинского района Санкт-Петербург
# 3848        136                                 ПроСинхро Москва
#
#                                                 value  \
# 222                     Санкт-Петейбург Созвездие Айс
# 2014                 Сахалинская область Холмск-Арент
# 4153                       Республика Мордовия СШОР 1
# 2706                                        МоФ Олимп
# 7730                                        Космос КО
# 2932  Санкт-Петербург ЦФКСиЗ Василеъстровского района
# 3739                                      МОСГОРСПОРТ
# 5028                              Северная ОлимпиЩ РК
# 6549                      СШОР Колпинского раТона СПБ
# 3848                                    ПроСинЭро МСК
#
#                                        candidate_name
# 222                     Созвездие Айс Санкт-Петербург
# 2014                 Холмск-Арена Сахалинская область
# 4153                       СШОР 1 Республика Мордовия
# 2706                                     Олимп Москва
# 7730                         Космос Калужская область
# 2932  ЦФКСиЗ Василеостровского района Санкт-Петербург
# 3739                               МОСГОРСПОРТ Москва
# 5028                 Северная Олимпия Республика Коми
# 6549          СШОР Колпинского района Санкт-Петербург
# 3848                                 ПроСинхро Москва

# %%
(test.title == test.candidate_name).sum()/test.shape[0]
# Out:
# 0.8154533844189017

# %% [markdown]
# При использовании модели LaBSE без доработок, точность подбора правильного ответа составила 82%. Попробуем обучить модель работать именно с нашими данными.

# %% [markdown]
# # LaBSE training

# %%
# Пример позитивных пар предложений
positive_pairs = train[['title', 'value']].values

# Создание списка InputExample
train_examples1 = [InputExample(texts=[s1, s2]) for s1, s2 in positive_pairs]

# Создание датасета и DataLoader
train_dataset = SentencesDataset(train_examples1, model=model)
train_dataloader = DataLoader(train_dataset, shuffle=True, batch_size=16)

# Определение функции потерь GISTEmbedLoss
guide_model = SentenceTransformer('distilbert-base-nli-stsb-mean-tokens')
train_loss = losses.GISTEmbedLoss(model=model, guide=guide_model)
# Out:
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/4.05k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/555 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/265M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/505 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
# Использование модели SentenceTransformer для обучения
model.fit(train_objectives=[(train_dataloader, train_loss)], epochs=2)
# Out:
#     <div>
#
#       <progress value='784' max='784' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [784/784 05:10, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>1.735600</td>
#     </tr>
#   </tbody>
# </table><p>

# %% [markdown]
# Проверка дообученноймодели на тестовых данных

# %%
corpus = model.encode(features.title.values)

# %%
query = model.encode(test.value.values)

# %%
model_search = semantic_search(query, corpus, top_k=1)

# %%
len(model_search)
# Out:
# 1566

# %%
test['search_id'] = [x[0]['corpus_id'] for x in model_search]

# %%
test['candidate_name_train'] = features.title.values[test.search_id.values]
test = test.drop(columns=['search_id'])

# %%
(test.title == test.candidate_name_train).sum()/test.shape[0]
# Out:
# 0.9227330779054917

# %%
test.sample(10)
# Out:
#       school_id                                              title  \
# 5558        265    Юность Ханты-Мансийский автономный округ - Югра
# 1405       1836                                      Триумф Москва
# 2699         84                Ледовое поколение Орловская область
# 5588         30                         Вилеса Айс Санкт-Петербург
# 3180        283                        Proice Kids Санкт-Петербург
# 5799        282  СШ ОРК филиала МО ЦСКА СКА г Санкт-Петербург С...
# 4548         46                        Динамо Владимирская область
# 6756         64                    Золотые надежды Санкт-Петербург
# 2284        216                          СШОР 6 Ростовская область
# 4880         43                      Движение Республика Татарстан
#
#                                                  value  \
# 5558   Ханты-Мансийский автономный офруг - Югра Юность
# 1405                                        Триумф МСХ
# 2699                              Оь Ледовое поколение
# 5588                                        Вилеса Айс
# 3180                       Санкт-Пеоербург Proice Kids
# 5799  СПБ СШ ОРК филиала МО ЦСКА СКА г Санкт-Петербург
# 4548                       Владимирская облЪсть Динамо
# 6756                               ЗолотыеМнадежды СПб
# 2284                                         РО СШОР 6
# 4880                                      ТвТ Движение
#
#                                          candidate_name  \
# 5558    Юность Ханты-Мансийский автономный округ - Югра
# 1405                                      Триумф Москва
# 2699                Ледовое поколение Орловская область
# 5588                         Вилеса Айс Санкт-Петербург
# 3180                        Proice Kids Санкт-Петербург
# 5799  СШ ОРК филиала МО ЦСКА СКА г Санкт-Петербург С...
# 4548                        Динамо Владимирская область
# 6756                    Золотые надежды Санкт-Петербург
# 2284                          СШОР 6 Ростовская область
# 4880                      Движение Республика Татарстан
#
#                                    candidate_name_train
# 5558    Юность Ханты-Мансийский автономный округ - Югра
# 1405                                      Триумф Москва
# 2699                Ледовое поколение Орловская область
# 5588                         Вилеса Айс Санкт-Петербург
# 3180                        Proice Kids Санкт-Петербург
# 5799  СШ ОРК филиала МО ЦСКА СКА г Санкт-Петербург С...
# 4548                        Динамо Владимирская область
# 6756                    Золотые надежды Санкт-Петербург
# 2284                          СШОР 6 Ростовская область
# 4880                      Движение Республика Татарстан

# %%
test[test['title'] != test['candidate_name_train']]
# Out:
#       school_id                                        title  \
# 809         134                       Прибой Санкт-Петербург
# 2763        119                                 Олимп Москва
# 2276        139                    Рассвет Красноярский край
# 3307        158                  Снеговик Краснодарский край
# 2868        175                   СШ ЗВС Ставропольский край
# ...         ...                                          ...
# 7743        173  СШ Ханты-Мансийский автономный округ - Югра
# 7241        126                 ОЛИМПИЯ Свердловская область
# 1887          9              Звездочка Архангельская область
# 5855        203                  СШОР 1 Оренбургская область
# 146          19       Арктур Ямало-Ненецкий автономный округ
#
#                           value                               candidate_name  \
# 809                      Прибой                       Прибой Санкт-Петербург
# 2763                      Олимп                                 Олимп Москва
# 2276  Красноярский крайЯРассвет                    Рассвет Красноярский край
# 3307                КК Енеговик                      Конек Чайковской Москва
# 2868                  СШ ЗВС Сщ                     СШ ЗВС Красноярский край
# ...                         ...                                          ...
# 7743                   ХАО-Ю УШ  СШ Ханты-Мансийский автономный округ - Югра
# 7241                 ОЛИМПИЯ СО                      ОЛИМПИЯ Санкт-Петербург
# 1887               Звеадочка АО                 АНО СК ЮНАРМЕЙЦЫ Севастополь
# 5855                     СШОИ 1                       СШОР 1 Республика Коми
# 146                      Урктур                      Ермак Иркутская область
#
#                                  candidate_name_train
# 809                          Прибой Тюменская область
# 2763                       Олимп Оренбургская область
# 2276                     Красноярск Красноярский край
# 3307                          Конек Чайковской Москва
# 2868                         СШ ЗВС Красноярский край
# ...                                               ...
# 7743  Юность Ханты-Мансийский автономный округ - Югра
# 7241                          ОЛИМПИЯ Санкт-Петербург
# 1887                      Юность Свердловская область
# 5855                           СШОР 1 Республика Коми
# 146                        УФФК Удмуртская Республика
#
# [121 rows x 5 columns]

# %% [markdown]
# Дообученная модель показала отличный результат на тестовых данных, опледеляет верную школу с точностью 0.92. Некоторые аугументации исказили название школы до неузнаваемости, но так же проблемы в определении возникают, когда школы с аналогичными названиями присутствуют в разных регионах. Так например школа Ангелы Плющенко есть как в Москве, так и в Московской области.
#
# Проверим модель на примере данных от заказчика

# %% [markdown]
# # LaBSE test on references

# %%
school_sample = sample

# %%
school_sample.sample(5)
# Out:
#      school_id                                               name
# 719         59                      Владимирская область, ДЮСШ №8
# 785         38                           ЧОУ ДО ДЮСШ "Голден Айс"
# 892          3  Республика Татарстан, МБУ ДО СШОР «ФСО "Авиатор"»
# 867         14      Московская область, МУ СШОР Альберта Демченко
# 136        244                     ГБУ ДО МАФК, школа Хрустальный

# %%
school_sample.shape
# Out:
# (895, 2)

# %% [markdown]
# Для начала очищаем данные от символов в названиях

# %%
# очищеннаем данные с помощью уже готовой функции
cleaned_text = []

for name in school_sample['name']:
    name = clean_text(name)
    cleaned_text.append(name)
school_sample['title'] = cleaned_text
school_sample = school_sample.drop(columns=['name'])

# %%
school_sample.sample(5)
# Out:
#      school_id                                           title
# 115        248  Московская область Центр спортивных технологий
# 783         40      Костромская область КО СШОР им АВ Голубева
# 718         60                  Иркутская обл МАУ АГО СШ Ермак
# 794         37            Нижегородская область НО СШОР по ЛВС
# 180        223                       Санкт-Петербург КФК ТИТУЛ

# %% [markdown]
# Создадим новый корпус текстов для кодирования в эмбеддинги и дальнейшего семантического поиска, используя уже дообученную модель LaBSE

# %%
query_sample = model.encode(school_sample.title.values)

# %%
model_search_sample = semantic_search(query_sample, corpus, top_k=1)

# %%
school_sample['search_id'] = [x[0]['corpus_id'] for x in model_search_sample]

# %%
school_sample['score'] = [x[0]['score'] for x in model_search_sample]

# %%
school_sample['candidate_name'] = features.title.values[school_sample.search_id.values]
school_sample['candidate_id'] = features.school_id.values[school_sample.search_id.values]
school_sample = school_sample.drop(columns=['search_id'])

# %%
school_sample_merged = school_sample.merge(reference, left_on='school_id', right_on='school_id', how='left')

# %%
school_sample_merged.sample(5)
# Out:
#      school_id                                           title     score  \
# 642         83  Ростовская область АНО СК ФКК Ледовая академия  0.796011
# 250        203                     Оренбургская область СШОР 1  0.967097
# 59         263                Мурманская область МАУ СШ Юность  0.827686
# 626         88                Республика Тататрстан СШ Ледокол  0.789805
# 767         46        Владимирская область ВРО ОГО ВФСО Динамо  0.756300
#
#                           candidate_name  candidate_id              name  \
# 642  Ледовая академия Ростовская область            83  Ледовая академия
# 250          СШОР 1 Оренбургская область           203            СШОР 1
# 59             Юность Мурманская область           263            Юность
# 626         Ледокол Республика Татарстан            88           Ледокол
# 767          Динамо Владимирская область            46            Динамо
#
#                    region
# 642    Ростовская область
# 250  Оренбургская область
# 59     Мурманская область
# 626  Республика Татарстан
# 767  Владимирская область

# %%
(school_sample.school_id == school_sample.candidate_id).sum()/school_sample.shape[0]
# Out:
# 0.7195530726256983

# %% [markdown]
# На рабочем примере данных точность модели упала до 0.72, необходимо проанализировать в каких случаях модель допускает ошибки. Для большей наглядности можно присоединить датасет с эталонными названиями к таблице с образцами и вывести те строки в которых было дано ошибочное предсказание

# %%
mistakes = school_sample_merged[school_sample_merged['school_id'] != school_sample_merged['candidate_id']]
mistakes = mistakes.sort_values(by='score')
mistakes.head(10)
# Out:
#      school_id                                              title     score  \
# 29         284                                  МО Коломяги Глайд  0.505180
# 68         259                     МО Финляндский АНО ФСО Чемпион  0.543609
# 745         50                                     КОГАУ СШ Дымка  0.568605
# 23         293                         АНО Лига фигурного катания  0.578950
# 853         19                                 ЯНАО МАУ СШ Арктур  0.579666
# 32         279                      МО Прометей КФК Созвездие Айс  0.584960
# 789         38                        МО Коломяги ДЮСШ Голден айс  0.586051
# 749         48  Санкт-Петрбург СПб ГБПОУ Академия ледовых видо...  0.600385
# 885          5                                            Айсдрим  0.606249
# 748         49                              МО 7-й округ Династия  0.609474
#
#                                         candidate_name  candidate_id  \
# 29                             Олимп Калужская область           118
# 68                     АНО ШФК Республика Башкортостан           292
# 745                          ДЮСШ 2 Курганская область            55
# 23          Армия фигурного катания Московская область            21
# 853        СШ Ханты-Мансийский автономный округ - Югра           173
# 32                     МосСпортОбъект ЛЦ Звезда Москва           294
# 789             МКУ ДЮСШ ВОСТОЧНАЯ Воронежская область           268
# 749  СШОР по фигурному катанию на коньках Санкт-Пет...           198
# 885                            Айсберг Республика Крым             6
# 748                           ДЮСШ 7 Иркутская область            58
#
#                            name                           region
# 29                        ГЛАЙД                  Санкт-Петербург
# 68                      Чемпион                  Санкт-Петербург
# 745                       Дымка                Кировская область
# 23   АНО Лига фигурного катания                           Москва
# 853                      Арктур  Ямало-Ненецкий автономный округ
# 32                Созвездие Айс                  Санкт-Петербург
# 789                  Голден айс                  Санкт-Петербург
# 749      Динамо Санкт-Петербург                  Санкт-Петербург
# 885          Ice Dream Айс Дрим                  Санкт-Петербург
# 748                    Династия                  Санкт-Петербург

# %%
mistakes.tail(10)
# Out:
#      school_id                                              title     score  \
# 830         26                         Брянская область СК Брянск  0.928731
# 832         26                         Брянская область СК Брянск  0.928731
# 828         26                         Брянская область СК Брянск  0.928731
# 288        197                 РМ СШОР по ФКК Республика Мордовия  0.936705
# 833         26                         СК Брянск Брянская область  0.939026
# 580         96  Москва Московская академия фигурного катания н...  0.952986
# 582         96  Москва Московская академия фигурного катания н...  0.953139
# 618         90               Свердловская обл МБОУ СШ 8 Локомотив  0.966430
# 298        194               Нижегородская область НО СШОР по ЛВС  0.973185
# 616         90           Свердловская область МБОУ СШ 8 Локомотив  0.973302
#
#                                         candidate_name  candidate_id  \
# 830                                СК Брянская область            36
# 832                                СК Брянская область            36
# 828                                СК Брянская область            36
# 288                    СШОР по ФКК Республика Мордовия           200
# 833                                СК Брянская область            36
# 580  Московская академия фигурного катания на коньк...           107
# 582  Московская академия фигурного катания на коньк...           107
# 618           МБОУ СШ 8 Локомотив Свердловская область           296
# 298               НО СШОР по ЛВС Нижегородская область            37
# 616           МБОУ СШ 8 Локомотив Свердловская область           296
#
#                                     name                 region
# 830                               Брянск       Брянская область
# 832                               Брянск       Брянская область
# 828                               Брянск       Брянская область
# 288  СШОР по фигурному катанию на конька    Республика Мордовия
# 833                               Брянск       Брянская область
# 580                                МАФКК                 Москва
# 582                                МАФКК                 Москва
# 618                            Локомотив   Свердловская область
# 298                          СШОР по ЛВС  Нижегородская область
# 616                            Локомотив   Свердловская область

# %% [markdown]
# После сортировки по уровню уверенности модели в полученном результате, можно сделать вывод, что в ситуациях, когда модель ошиблась, но показывала вероятность правильного ответа около 0.9 проблема видна либо в том, что названия очень близки, либо в эталонной таблице присутствуют скрытые дубликаты. Так например модель отностит "Свердловская область МБОУ СШ 8 Локомотив" к "МБОУ СШ 8 Локомотив Свердловская область", а по разметке подразумевалась школа Локомотив Свердловская область, что возможно является одной и той же школой. Так же например "Нижегородская область НО СШОР по ЛВС" отнесена к "НО СШОР по ЛВС Нижегородская область", а должна к СШОР по ЛВС Нижегородская область.
#
# Из тех школ, которым модель присвоила id с трудом, некоторые школы из Санкт-Петербурга имеют районную приставку которая очень путает модель (СШ Фрунзенского района, Колпинского района, МО Финляндский, МО Коломяги), так как эти вариации названий отсутствовали в эталонном датасете.

# %% [markdown]
# # Анализ результата исследования

# %% [markdown]
# Было проведено исследование данных заказчика. Для анализа были предоставлены два небольших набора данных - с эталонными названиями школ и и с примерами их разного написания.
#
# Так как данных для построения модели не достаточно было принято решение создать собственный датасет для обучения, используя эталонные наименования. Датасет был расширен путем добавления различных комбинаций из названия + региона, аббервиатуры региона, его сокращения, а так же путем внесения орфографических ошибок в получившееся наименование.
#
# В результате таких комбинаций был подготовлен датасет на 7830 строк и разделен на тестовый и тренировочный.
#
# В качестве модели были опробованы 2 модели DeepPavlov и LaBSE из sentence-transformers huggingface. DeepPavlov показала намного более долгий процесс обучения и более низкий результат в базовой версии. Поэтому была выбрана модель LaBSE. Эту модель можно использовать для отображения 109 языков в общее векторное пространство. Она очень хорошо работает так же с текстами на русском языке, но без доработки показала результат 82% точности.
#
# Тренировочный датасет был использован для дообучения модели, после чего ее результат улучшился **до 92% точности**.
#
# На данных заказчика метрика модели показала значение 72% точности.
#
# После анализа ошибок, которые допустила модель на пользовательском вводе данных, можно сделать вывод, что в ситуациях, когда модель ошиблась, но показывала вероятность правильного ответа около 90% проблема видна либо в том, что названия очень близки, либо в эталонной таблице присутствуют скрытые дубликаты. Так например модель отностит "Свердловская область МБОУ СШ 8 Локомотив" к "МБОУ СШ 8 Локомотив Свердловская область", что возможно является одной и той же школой. Так же например "Нижегородская область НО СШОР по ЛВС" отнесена к "НО СШОР по ЛВС Нижегородская область", что возможно так же является одной и той же школой.
#
# Из тех школ, которым модель присвоила id с трудом, некоторые школы из Санкт-Петербурга имеют районную приставку которая очень путает модель (СШ Фрунзенского района, Колпинского района, МО Финляндский, МО Коломяги), так как подобные варианты отсутствовали в эталонном датасете.
#
# Это только некоторые примеры, в которых модель вероятно могла бы сделать верные предсказания, имея более выверенный датасет с эталонными названиями школ.
#
# Так же проблемы в определении возникают, когда школы с аналогичными названиями присутствуют в разных регионах. Так например школа Ангелы Плющенко есть как в Москве, так и в Московской области.

# %% [markdown]
# **Модель, использованная в исследовании**
# - SentenceTransformer('sentence-transformers/LaBSE').
# - Так же для поиска реультата была использована утилита из sentence_transformers - semantic_search, которая сравнивает полученные в результате кодирования эмбеддинги и находит максимально похожую пару.

# %% [markdown]
# **Для оценки результата** использовалась метрика Точность (Accuracy) — она измеряет долю правильных предсказаний по отношению к общему числу предсказаний. Точность показывает, насколько хорошо модель или система распознаёт или предсказывает значения.

# %% [markdown]
# **Инструкция по запуску модели:**

# %%
#очистить ваши данные от лишних символов и абберевиатур с помощью функции
#cleaned_text = []

#for name in ВАША_ТАБЛИЦА['name']:
    #name = clean_text(name)
    #cleaned_text.append(name)
#ВАША_ТАБЛИЦА['title'] = cleaned_text
#ВАША_ТАБЛИЦА = ВАША_ТАБЛИЦА.drop(columns=['name'])
#вместо колонки name появится колонка title с очищенным названием

# %%
#query = model.encode(ВАША_ТАБЛИЦА.title.values)
#закодировать названия в эмбеддинги с помощью предобученной модели

# %%
#model_search = semantic_search(query, corpus, top_k=1)
#провести поиск семантического сходства с эталонной таблицей, заранее записанной в corpus

# %%
#ВАША_ТАБЛИЦА['search_id'] = [x[0]['corpus_id'] for x in model_search]
#ВАША_ТАБЛИЦА['candidate_name'] = features.title.values[ВАША_ТАБЛИЦА.search_id.values]
#ВАША_ТАБЛИЦА = ВАША_ТАБЛИЦА.drop(columns=['search_id'])
#добавляем в таблицу эталонное название, для наглядности

# %% [markdown]
# **Рекомендации заказчику**

# %% [markdown]
# Для дальнейшего улучшения работы модели необходимо доработать датасет с эталонными названиями, исключить дубли. Так же было бы полезно присвоить каждой школе какой-то уникальный код, например ИНН, который в дальнейшем могли бы указывать представители школ прирегистрации на соревнование. Это создаст задел на будущее, который упростит идентификацию бюджетных учреждений, так как именно они имеют самые сложные буквенные наименования.

# %%
pip freeze > requirements.txt
